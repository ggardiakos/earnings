# %%
from earnings.account import Account
from earnings.broker import Broker
from earnings.scanner import Scanner

# %%
broker = Broker()
account = Account()

# %%
quotes = broker.get_quotes(['GOOG', 'AMZN', 'NFLX', 'AAPL', 'FB'])
quotes
# Out:
#          mark mark_change mark_pct_change    volume
# GOOG  2768.12     -0.0001             0.0    629029
# AMZN  3293.97         0.0             0.0   2056699
# NFLX   515.92         0.0             0.0   2177736
# AAPL    149.1         0.0             0.0  59375009
# FB     363.18         0.0             0.0   7195724

# %%
balances = account.get_balances()
balances
# Out:
# balance        30434.9
# equity         33144.4
# free_margin    19257.1
# used_margin    13887.3
# dtype: float64

# %%
orders = account.get_orders()
orders
# Out:
#    session          duration order_type complex_order_strategy_type  quantity  \
# 0   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
# 1   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       2.0
# 2   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                 IRON_CONDOR       1.0
# 3   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
# 4   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
# 5   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
# 6   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       2.0
# 7   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
# 8   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
# 9   NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    VERTICAL       1.0
# 10  NORMAL  GOOD_TILL_CANCEL  NET_DEBIT                    STRANGLE       1.0
#
#     filled_quantity  remaining_quantity  price  \
# 0               0.0                 1.0   0.75
# 1               0.0                 2.0   0.39
# 2               0.0                 1.0   1.11
# 3               0.0                 1.0   0.80
# 4               0.0                 1.0   0.90
# 5               0.0                 1.0   0.90
# 6               0.0                 2.0   0.55
# 7               0.0                 1.0   0.86
# 8               0.0                 1.0   0.85
# 9               0.0                 1.0   1.06
# 10              0.0                 1.0   0.86
#
#                                  order_leg_collection    order_id  cancelable  \
# 0   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4710065932        True
# 1   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4728482390        True
# 2   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4711796059        True
# 3   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4711796058        True
# 4   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4688664512        True
# 5   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4738789826        True
# 6   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4709634561        True
# 7   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4705010793        True
# 8   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4699558740        True
# 9   [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4689719919        True
# 10  [{'orderLegType': 'OPTION', 'legId': 1, 'instr...  4724294861        True
#
#     status              entered_time
# 0   QUEUED  2021-08-04T17:31:19+0000
# 1   QUEUED  2021-08-10T16:34:55+0000
# 2   QUEUED  2021-08-05T10:26:36+0000
# 3   QUEUED  2021-08-05T10:26:21+0000
# 4   QUEUED  2021-07-29T15:21:19+0000
# 5   QUEUED  2021-08-12T19:45:06+0000
# 6   QUEUED  2021-08-04T16:31:11+0000
# 7   QUEUED  2021-08-03T16:48:17+0000
# 8   QUEUED  2021-08-02T15:07:35+0000
# 9   QUEUED  2021-07-29T17:42:38+0000
# 10  QUEUED  2021-08-09T17:22:27+0000

# %%
positions = account.get_positions()
positions
# Out:
#    underlying asset_type  qty option_type expiration_date strike  price  \
# 0         CCL     OPTION -1.0        CALL         17SEP21     25  0.653
# 1         CCL     OPTION -1.0         PUT         17SEP21     20  1.023
# 2         EWZ     OPTION -2.0        CALL         17SEP21     41  0.353
# 3         EWZ     OPTION -2.0         PUT         17SEP21     34  0.403
# 4          GS     OPTION  1.0        CALL         17SEP21    425  1.877
# 5          GS     OPTION -1.0        CALL         17SEP21    415  3.043
# 6          GS     OPTION -1.0         PUT         17SEP21    385  3.883
# 7          GS     OPTION  1.0         PUT         17SEP21    375  2.617
# 8         HLT     OPTION -1.0        CALL         17SEP21    140  0.593
# 9         HLT     OPTION -1.0         PUT         17SEP21    110  1.193
# 10         KR     OPTION -2.0        CALL         17SEP21     46  0.533
# 11         KR     OPTION -2.0         PUT         17SEP21     39  0.553
# 12        KRE     OPTION -1.0        CALL         17SEP21     68  0.703
# 13        KRE     OPTION -1.0         PUT         17SEP21     57  0.793
# 14        LVS     OPTION -1.0        CALL         17SEP21     45  0.883
# 15        LVS     OPTION -1.0         PUT         17SEP21     35  0.833
# 16         MU     OPTION -1.0        CALL         17SEP21     90  0.753
# 17         MU     OPTION -1.0         PUT         17SEP21   72.5  0.943
# 18         PM     OPTION -1.0         PUT         17SEP21     95  1.033
# 19         PM     OPTION -1.0        CALL         17SEP21    105  0.763
# 20       PYPL     OPTION -1.0         PUT         17SEP21    270  5.463
# 21       PYPL     OPTION  1.0         PUT         17SEP21    260  3.357
# 22        UAL     OPTION -1.0        CALL         17SEP21   52.5  0.733
# 23        UAL     OPTION -1.0         PUT         17SEP21     38  0.843
# 24          V     OPTION  1.0        CALL         17SEP21    260  0.857
# 25          V     OPTION -1.0        CALL         17SEP21    250  2.123
# 26          V     OPTION -1.0         PUT         17SEP21    220  2.333
# 27          V     OPTION  1.0         PUT         17SEP21    210  1.397
# 28        XLU     OPTION  1.0        CALL         17SEP21     70  0.307
# 29        XLU     OPTION -1.0        CALL         17SEP21     66  1.963
# 30        XLU     OPTION -1.0         PUT         17SEP21     66  1.123
# 31        XLU     OPTION  1.0         PUT         17SEP21     61  0.297
# 32        TLT     OPTION  1.0         PUT         20AUG21    138  0.377
#
#     value  pal_day  buying_power
# 0   -63.0      0.0         743.8
# 1   -48.5      0.0          48.5
# 2   -40.0      0.0          40.0
# 3   -95.0      0.0         986.2
# 4   585.0      0.0        1000.0
# 5  -952.5      0.0           0.0
# 6  -445.0      0.0           0.0
# 7   289.0      0.0           0.0
# 8   -40.0      0.0          40.0
# 9  -130.0      0.0        1353.2
# 10  -89.0      0.0        1163.4
# 11  -75.0      0.0          75.0
# 12 -119.5      0.0        1227.5
# 13  -20.0      0.0          20.0
# 14  -53.0      0.0         452.0
# 15  -51.0      0.0          51.0
# 16  -10.0      0.0          10.0
# 17 -375.0      0.0        1789.0
# 18  -46.0      0.0          46.0
# 19  -74.5      0.0        1765.3
# 20 -597.5      0.0        1000.0
# 21  312.5      0.0           0.0
# 22  -61.5      0.0         525.4
# 23  -51.0      0.0          51.0
# 24   26.0      0.0        1000.0
# 25  -79.0      0.0           0.0
# 26 -188.5      0.0           0.0
# 27   98.0      0.0           0.0
# 28   46.5      0.0         400.0
# 29 -328.5      0.0           0.0
# 30  -51.0      0.0         100.0
# 31   16.5      0.0           0.0
# 32    1.0      0.0           0.0

# %%
Scanner().earnings()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_417285/3744646222.py in <module>
# ----> 1 Scanner().earnings()
#
# ~/Desktop/GitHub/Projects/earnings/earnings/scanner.py in earnings(self)
#      63             symbol, market cap (billions), price, changes (decimal), time (before/after market)
#      64         """
# ---> 65         earnings = self._get_earnings()
#      66         earnings = self._clean_earnings(earnings)
#      67         return earnings
#
# ~/Desktop/GitHub/Projects/earnings/earnings/scanner.py in _get_earnings(self)
#      76             # Post login form
#      77             session.post(self.login_url,
# ---> 78                          data=self.login_details,
#      79                          headers=self.headers)
#      80
#
# ~/Desktop/GitHub/Projects/earnings/earnings/scanner.py in login_details(self)
#      51         password = os.environ.get('FINVIZ_PASSWORD')
#      52         if not email or not password:
# ---> 53             raise Exception(
#      54                 'Please set required env. variables ( FINVIZ_EMAIL , FINVIZ_PASSWORD )'
#      55             )
#
# Exception: Please set required env. variables ( FINVIZ_EMAIL , FINVIZ_PASSWORD )
